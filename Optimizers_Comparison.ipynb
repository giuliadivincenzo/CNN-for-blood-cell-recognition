# %% [markdown]
# ## ⚙️ Import Libraries

# %% [markdown]
# ##Connect to Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/PROVE
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/PROVE

# %%
# !pip install keras_cv
# Out:
# Requirement already satisfied: keras_cv in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras_cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras_cv) (4.9.7)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.1.7)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (1.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (4.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import requests
from io import BytesIO
import cv2
from PIL import Image
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import compute_class_weight
import seaborn as sns
import keras_cv.layers as kcvl

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %%
import albumentations as A
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
pip install --upgrade albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.4.21)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (2.9.2)
# Requirement already satisfied: albucore==0.0.20 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.20)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.20->albumentations) (3.10.10)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.20->albumentations) (6.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (4.12.2)

# %% [markdown]
# ## ⏳ Load Data

# %% [markdown]
# ## For Kaggle

# %%
data = np.load('/kaggle/input/initial-dataset/training_set.npz')
X = data['images']
y = data['labels']

# %% [markdown]
# ## For Colab

# %%
data = np.load('training_set.npz')
X = data['images']
y = data['labels']

# %%
X = X[:11958]
y = y[:11958]
classes = np.array(np.unique(y))
class_names = ['Basophil','Eosinophil','Erythroblast','Immature granulocytes','Lymphocyte','Monocyte','Neutrophil','Platelet']
print(classes)
print(class_names)
# Out:
# [0 1 2 3 4 5 6 7]
# ['Basophil', 'Eosinophil', 'Erythroblast', 'Immature granulocytes', 'Lymphocyte', 'Monocyte', 'Neutrophil', 'Platelet']

# %%
# Ensure that y is a flat array of integers
y_flat = np.array(y).flatten()


# Get unique classes in `y_flat`
classes = np.unique(y_flat)

# Compute class weights
class_weights = compute_class_weight('balanced', classes=classes, y=y_flat)

# Convert class weights in dictionary
class_weights_dict = dict(enumerate(class_weights))

# Print class weights
print(class_weights_dict)
# Out:
# {0: 1.7544014084507042, 1: 0.6853507565337001, 2: 1.3776497695852534, 3: 0.7377838104639685, 4: 1.762676886792453, 5: 1.505287009063444, 6: 0.6415236051502146, 7: 0.9097687157638467}

# %% [markdown]
# ## 🔎 Inspect Data

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed, test_size=0.25, stratify=y)

# Split test set into validation and test sets with stratification
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, random_state=seed, test_size=0.5, stratify=y_test)

# Convert targets to categorical
y_train = tfk.utils.to_categorical(y_train, num_classes=len(class_names))
y_val = tfk.utils.to_categorical(y_val, num_classes=len(class_names))
y_test = tfk.utils.to_categorical(y_test, num_classes=len(class_names))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8968, 96, 96, 3), y_train shape: (8968, 8)
# X_val shape: (1495, 96, 96, 3), y_val shape: (1495, 8)
# X_test shape: (1495, 96, 96, 3), y_test shape: (1495, 8)

# %%
# Definire una pipeline di trasformazioni
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=45, p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.HueSaturationValue(hue_shift_limit=40, sat_shift_limit=30, val_shift_limit=20, p=0.3),
    A.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1, p=0.3),
    A.Defocus(radius=(1,3), alias_blur=(0.5, 0.5), p=0.3),
    A.CLAHE(clip_limit=(3, 3), tile_grid_size=(8, 8), p=0.3),
    A.Downscale(scale_range=(0.5, 0.75), interpolation_pair={'downscale': cv2.INTER_NEAREST, 'upscale': cv2.INTER_LINEAR}, p=0.3),
    A.GaussNoise(p=0.2),
    A.RandomCrop(height=70,width=70, p=0.3),
    A.RandomScale(scale_limit=0.6, p=0.2),
    A.Resize(96, 96)  # Guarantee that all images are 96x96
])

# %%
# Apply transformation to the whole training dataset
X_augmented = []

for img in X_train:
    augmented = transform(image=img)
    X_augmented.append(augmented["image"])

# Convert the transformed dataset into a NumPy array
X_augmented = np.array(X_augmented)

# %%
print(f"X_train shape: {X_train.shape}, X_augmented shape: {X_augmented.shape}")
# Out:
# X_train shape: (8968, 96, 96, 3), X_augmented shape: (8968, 96, 96, 3)

# %% [markdown]
# ## 🛠️ General settings

# %%
from keras.applications.efficientnet_v2 import EfficientNetV2M

# %%
from tensorflow.keras.layers import LayerNormalization, GroupNormalization

# %%
# Initialise EfficientNetV2M model with pretrained weights, for transfer learning
eff = tfk.applications.EfficientNetV2M(
    input_shape=(96, 96, 3),
    include_top=False,
    weights='imagenet',
    include_preprocessing=True,
)
eff.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step

# %% [markdown]
# ## 🛠️ Transfer Learning with Lion

# %%
# Optimizer with exponential decay
optimizer = tf.keras.optimizers.Lion(1e-4)

# ReduceLROnPlateau for fine adjustments
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',  # Monitor validation accuracy
    factor=0.5,              # Halve the learning rate
    patience=5,             # Wait 10 epochs for no improvement
    min_lr=1e-6,             # Minimum learning rate
    verbose=1                # Log learning rate changes
)

# %%
#DEF OF CUSTOM MODEL
def build_eff_aug(input_shape=(96, 96, 3)):

    """Build a ConvNeXtLarge-based CNN with image augmentation"""

    # Input layer
    inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

    # EfficientNet base model
    x = eff(inputs)

    # Inception Block
    def inception_block(inputs):
        tower_1 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_1 = tfkl.Conv2D(64, (3, 3), padding='same', activation='relu')(tower_1)

        tower_2 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_2 = tfkl.Conv2D(64, (5, 5), padding='same', activation='relu')(tower_2)

        tower_3 = tfkl.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(inputs)
        tower_3 = tfkl.Conv2D(64, (1, 1), activation='relu')(tower_3)

        output = tfkl.concatenate([tower_1, tower_2, tower_3], axis=-1)
        return output

    x = inception_block(x)

    # Flatten and fully connected layers with Group Normalization
    x = tfkl.Flatten()(x)
    x = tfkl.Dropout(0.5)(x)
    x = GroupNormalization(groups=8, axis=-1)(x)
    x = tfkl.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(1e-5), name='dense_128')(x)
    x = tfkl.Dropout(0.1)(x)

    # Output layer
    outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense')(x)

    # Final model
    model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

    # Compile the model
    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        optimizer=optimizer,
        metrics=['accuracy']
    )
    # Return the model
    return model

# %%
# Build an EffNet based custom  model for transfer learning with Lion
tl_model_Lion = build_eff_aug()

# Train the model
tl_history_Lion = tl_model_Lion.fit(
    x=X_augmented,
    y=y_train,
    batch_size=64,
    epochs=30,
    validation_data=(X_val, y_val),
    class_weight = class_weights_dict,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True
        ),
        reduce_lr  # Add dynamic learning rate adjustment
    ]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history_Lion['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = 'CNN_' + str(final_val_accuracy) + '.keras'
tl_model_Lion.save(model_filename)

# Save weights of the Transfer Learning model
tl_model_Lion.save_weights('tl.weights.h5')

# Free memory by deleting the model instance
del tl_model_Lion
# Out:
# Epoch 1/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 175s 700ms/step - accuracy: 0.2422 - loss: 2.1300 - val_accuracy: 0.7398 - val_loss: 1.1234 - learning_rate: 1.0000e-04
# Epoch 2/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━
# Epoch 27/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.8722 - loss: 0.7796 - val_accuracy: 0.9191 - val_loss: 0.7565 - learning_rate: 5.0000e-05
# Epoch 28/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 86ms/step - accuracy: 0.8716 - loss: 0.7705 - val_accuracy: 0.9177 - val_loss: 0.7529 - learning_rate: 5.0000e-05
# Epoch 29/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.8735 - loss: 0.7645 - val_accuracy: 0.9204 - val_loss: 0.7559 - learning_rate: 5.0000e-05
# Epoch 30/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.8718 - loss: 0.7614 - val_accuracy: 0.9191 - val_loss: 0.7612 - learning_rate: 5.0000e-05
# Final validation accuracy: 92.04%

# %% [markdown]
# ## 🛠️ Transfer Learning with Adam

# %%
# Optimizer with exponential decay
optimizer = tf.keras.optimizers.Adam(1e-4)

# ReduceLROnPlateau for fine adjustments
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',  # Monitor validation accuracy
    factor=0.5,              # Halve the learning rate
    patience=5,             # Wait 10 epochs for no improvement
    min_lr=1e-6,             # Minimum learning rate
    verbose=1                # Log learning rate changes
)

# %%
#DEF OF CUSTOM MODEL
def build_eff_aug(input_shape=(96, 96, 3)):

    """Build a ConvNeXtLarge-based CNN with image augmentation"""

    # Input layer
    inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

    # EfficientNet base model
    x = eff(inputs)

    # Inception Block
    def inception_block(inputs):
        tower_1 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_1 = tfkl.Conv2D(64, (3, 3), padding='same', activation='relu')(tower_1)

        tower_2 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_2 = tfkl.Conv2D(64, (5, 5), padding='same', activation='relu')(tower_2)

        tower_3 = tfkl.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(inputs)
        tower_3 = tfkl.Conv2D(64, (1, 1), activation='relu')(tower_3)

        output = tfkl.concatenate([tower_1, tower_2, tower_3], axis=-1)
        return output

    x = inception_block(x)

    # Flatten and fully connected layers with Group Normalization
    x = tfkl.Flatten()(x)
    x = tfkl.Dropout(0.5)(x)
    x = GroupNormalization(groups=8, axis=-1)(x)
    x = tfkl.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(1e-5), name='dense_128')(x)
    x = tfkl.Dropout(0.1)(x)


    # Output layer
    outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense')(x)

    # Final model
    model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

    # Compile the model
    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        optimizer=optimizer,
        metrics=['accuracy']
    )
    # Return the model
    return model

# %%
# Build an EffNet based custom  model for transfer learning with Adam
tl_model_Adam = build_eff_aug()

# Train the model
tl_history_Adam = tl_model_Adam.fit(
    x=X_augmented,
    y=y_train,
    batch_size=64,
    epochs=30,
    validation_data=(X_val, y_val),
    class_weight = class_weights_dict,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True
        ),
        reduce_lr  # Add dynamic learning rate adjustment
    ]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history_Adam['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = 'CNN_' + str(final_val_accuracy) + '.keras'
tl_model_Adam.save(model_filename)

# Save weights of the Transfer Learning model
tl_model_Adam.save_weights('tl.weights.h5')

# Free memory by deleting the model instance
del tl_model_Adam
# Out:
# Epoch 1/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 148s 535ms/step - accuracy: 0.2207 - loss: 2.2015 - val_accuracy: 0.6729 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 2/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 40s 83ms/step - accuracy: 0.4164 - loss: 1.6912 - val_accuracy: 0.7625 - val_loss: 1.0781 - learning_rate: 1.0000e-04
# Epoch 3/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.5014 - loss: 1.5090 - val_accuracy: 0.7987 - val_loss: 1.0232 - learning_rate: 1.0000e-04
# Epoch 4/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.5649 - loss: 1.3934 - val_accuracy: 0.8301 - val_loss: 1.0036 - learning_rate: 1.0000e-04
# Epoch 5/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0
# Epoch 29/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.8201 - loss: 0.8990 - val_accuracy: 0.9124 - val_loss: 0.8245 - learning_rate: 5.0000e-05
# Epoch 30/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 19s 82ms/step - accuracy: 0.8126 - loss: 0.8926 - val_accuracy: 0.9097 - val_loss: 0.8194 - learning_rate: 5.0000e-05
# Final validation accuracy: 91.24%

# %% [markdown]
# ## 🛠️ Transfer Learning with AdamW

# %%
# Optimizer with exponential decay
optimizer = tf.keras.optimizers.AdamW(1e-4)

# ReduceLROnPlateau for fine adjustments
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',  # Monitor validation accuracy
    factor=0.5,              # Halve the learning rate
    patience=5,             # Wait 10 epochs for no improvement
    min_lr=1e-6,             # Minimum learning rate
    verbose=1                # Log learning rate changes
)

# %%
#DEF OF CUSTOM MODEL
def build_eff_aug(input_shape=(96, 96, 3)):

    """Build a ConvNeXtLarge-based CNN with image augmentation"""

    # Input layer
    inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

    # EfficientNet base model
    x = eff(inputs)

    # Inception Block
    def inception_block(inputs):
        tower_1 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_1 = tfkl.Conv2D(64, (3, 3), padding='same', activation='relu')(tower_1)

        tower_2 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_2 = tfkl.Conv2D(64, (5, 5), padding='same', activation='relu')(tower_2)

        tower_3 = tfkl.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(inputs)
        tower_3 = tfkl.Conv2D(64, (1, 1), activation='relu')(tower_3)

        output = tfkl.concatenate([tower_1, tower_2, tower_3], axis=-1)
        return output

    x = inception_block(x)

    # Flatten and fully connected layers with Group Normalization
    x = tfkl.Flatten()(x)
    x = tfkl.Dropout(0.5)(x)
    x = GroupNormalization(groups=8, axis=-1)(x)
    x = tfkl.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(1e-5), name='dense_128')(x)
    x = tfkl.Dropout(0.1)(x)

    # Output layer
    outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense')(x)

    # Final model
    model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

    # Compile the model
    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        optimizer=optimizer,
        metrics=['accuracy']
    )
    # Return the model
    return model

# %%
# Build an EffNet based custom  model for transfer learning with AdamW
tl_model_AdamW = build_eff_aug()

# Train the model
tl_history_AdamW = tl_model_AdamW.fit(
    x=X_augmented,
    y=y_train,
    batch_size=64,
    epochs=30,
    validation_data=(X_val, y_val),
    class_weight = class_weights_dict,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True
        ),
        reduce_lr  # Add dynamic learning rate adjustment
    ]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history_AdamW['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = 'CNN_' + str(final_val_accuracy) + '.keras'
tl_model_AdamW.save(model_filename)

# Save weights of the Transfer Learning model
tl_model_AdamW.save_weights('tl.weights.h5')

# Free memory by deleting the model instance
del tl_model_AdamW
# Out:
# Epoch 1/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 151s 533ms/step - accuracy: 0.1875 - loss: 2.2970 - val_accuracy: 0.5391 - val_loss: 1.3576 - learning_rate: 1.0000e-04
# Epoch 2/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.3978 - loss: 1.7269 - val_accuracy: 0.7117 - val_loss: 1.1222 - learning_rate: 1.0000e-04
# Epoch 3/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5184 - loss: 1.4893 - val_accuracy: 0.7579 - val_loss: 1.0802 - learning_rate: 1.0000e-04
# Epoch 4/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 91ms/step - accuracy: 0.5889 - loss: 1.3734 - val_accuracy: 0.8114 - val_loss: 1.0332 - learning_rate: 1.0000e-04
# Epoch 5/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6200 - loss: 1.3153 - val_accuracy: 0.8301 - val_loss: 0.9691 - learning_rate: 1.0000e-04
# Epoch 6/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.6634 - loss: 1.2464 - val_accuracy: 0.8622 - val_loss: 0.9719 - learning_rate: 1.0000e-04
# Epoch 7/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - accuracy: 0.6685 - loss: 1.2070 - val_accuracy: 0.8656 - val_loss: 0.9565 - learning_rate: 1.0000e-04
# Epoch 8/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.6904 - loss: 1.1748 - val_accuracy: 0.8709 - val_loss: 0.9243 - learning_rate: 1.0000e-04
# Epoch 9/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.7035 - loss: 1.1293 - val_accuracy: 0.8669 - val_loss: 0.9639 - learning_rate: 1.0000e-04
# Epoch 10/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.7143 - loss: 1.1323 - val_accuracy: 0.8742 - val_loss: 0.9524 - learning_rate: 1.0000e-04
# Epoch 11/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.7206 - loss: 1.1067 - val_accuracy: 0.8823 - val_loss: 0.9234 - learning_rate: 1.0000e-04
# Epoch 12/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.7397 - loss: 1.0800 - val_accuracy: 0.8823 - val_loss: 0.9025 - learning_rate: 1.0000e-04
# Epoch 13/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.7454 - loss: 1.0654 - val_accuracy: 0.8816 - val_loss: 0.9414 - learning_rate: 1.0000e-04
# Epoch 14/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.7603 - loss: 1.0312 - val_accuracy: 0.8849 - val_loss: 0.9076 - learning_rate: 1.0000e-04
# Epoch 15/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.7592 - loss: 1.0258 - val_accuracy: 0.8849 - val_loss: 0.9140 - learning_rate: 1.0000e-04
# Epoch 16/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 19s 82ms/step - accuracy: 0.7622 - loss: 1.0252 - val_accuracy: 0.8876 - val_loss: 0.8970 - learning_rate: 1.0000e-04
# Epoch 17/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 91ms/step - accuracy: 0.7726 - loss: 1.0106 - val_accuracy: 0.8943 - val_loss: 0.8801 - learning_rate: 1.0000e-04
# Epoch 18/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - accuracy: 0.7727 - loss: 0.9922 - val_accuracy: 0.8970 - val_loss: 0.8605 - learning_rate: 1.0000e-04
# Epoch 19/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - accuracy: 0.7804 - loss: 0.9822 - val_accuracy: 0.8896 - val_loss: 0.8702 - learning_rate: 1.0000e-04
# Epoch 20/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 86ms/step - accuracy: 0.7826 - loss: 0.9716 - val_accuracy: 0.8930 - val_loss: 0.8514 - learning_rate: 1.0000e-04
# Epoch 21/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - accuracy: 0.7844 - loss: 0.9691 - val_accuracy: 0.8943 - val_loss: 0.8447 - learning_rate: 1.0000e-04
# Epoch 22/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.7900 - loss: 0.9598 - val_accuracy: 0.8983 - val_loss: 0.8641 - learning_rate: 1.0000e-04
# Epoch 23/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.7957 - loss: 0.9475 - val_accuracy: 0.8950 - val_loss: 0.8467 - learning_rate: 1.0000e-04
# Epoch 24/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.7924 - loss: 0.9439 - val_accuracy: 0.9017 - val_loss: 0.8275 - learning_rate: 1.0000e-04
# Epoch 25/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.7984 - loss: 0.9356 - val_accuracy: 0.9017 - val_loss: 0.8299 - learning_rate: 1.0000e-04
# Epoch 26/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.8066 - loss: 0.9309 - val_accuracy: 0.8990 - val_loss: 0.8457 - learning_rate: 1.0000e-04
# Epoch 27/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.8067 - loss: 0.9247 - val_accuracy: 0.9043 - val_loss: 0.8325 - learning_rate: 1.0000e-04
# Epoch 28/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.8115 - loss: 0.9149 - val_accuracy: 0.9023 - val_loss: 0.8251 - learning_rate: 1.0000e-04
# Epoch 29/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 86ms/step - accuracy: 0.8165 - loss: 0.9063 - val_accuracy: 0.9023 - val_loss: 0.8208 - learning_rate: 1.0000e-04
# Epoch 30/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.8109 - loss: 0.9114 - val_accuracy: 0.8990 - val_loss: 0.8281 - learning_rate: 1.0000e-04
# Final validation accuracy: 90.43%

# %% [markdown]
# ## 🛠️ Transfer Learning with Experimental SGD

# %%
# Optimizer with exponential decay
optimizer = tf.keras.optimizers.SGD(1e-4)

# ReduceLROnPlateau for fine adjustments
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',  # Monitor validation accuracy
    factor=0.5,              # Halve the learning rate
    patience=5,             # Wait 10 epochs for no improvement
    min_lr=1e-6,             # Minimum learning rate
    verbose=1                # Log learning rate changes
)

# %%
#DEF OF CUSTOM MODEL
def build_eff_aug(input_shape=(96, 96, 3)):

    """Build a ConvNeXtLarge-based CNN with image augmentation"""

    # Input layer
    inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

    # EfficientNet base model
    x = eff(inputs)

    # Inception Block
    def inception_block(inputs):
        tower_1 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_1 = tfkl.Conv2D(64, (3, 3), padding='same', activation='relu')(tower_1)

        tower_2 = tfkl.Conv2D(64, (1, 1), activation='relu')(inputs)
        tower_2 = tfkl.Conv2D(64, (5, 5), padding='same', activation='relu')(tower_2)

        tower_3 = tfkl.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(inputs)
        tower_3 = tfkl.Conv2D(64, (1, 1), activation='relu')(tower_3)

        output = tfkl.concatenate([tower_1, tower_2, tower_3], axis=-1)
        return output

    x = inception_block(x)

    # Flatten and fully connected layers with Group Normalization
    x = tfkl.Flatten()(x)
    x = tfkl.Dropout(0.5)(x)
    x = GroupNormalization(groups=8, axis=-1)(x)
    x = tfkl.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(1e-5), name='dense_128')(x)
    x = tfkl.Dropout(0.1)(x)

    # Output layer
    outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense')(x)

    # Final model
    model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

    # Compile the model
    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        optimizer=optimizer,
        metrics=['accuracy']
    )
    # Return the model
    return model

# %%
# Build an EffNet based custom  model for transfer learning with SGD
tl_model_SGD = build_eff_aug()

# Train the model
tl_history_SGD = tl_model_SGD.fit(
    x=X_augmented,
    y=y_train,
    batch_size=64,
    epochs=30,
    validation_data=(X_val, y_val),
    class_weight = class_weights_dict,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True
        ),
        reduce_lr  # Add dynamic learning rate adjustment
    ]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history_SGD['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = 'CNN_' + str(final_val_accuracy) + '.keras'
tl_model_SGD.save(model_filename)

# Save weights of the Transfer Learning model
tl_model_SGD.save_weights('tl.weights.h5')

# Free memory by deleting the model instance
del tl_model_SGD
# Out:
# Epoch 1/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 148s 552ms/step - accuracy: 0.1076 - loss: 2.7068 - val_accuracy: 0.0656 - val_loss: 2.4728 - learning_rate: 1.0000e-04
# Epoch 2/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.1169 - loss: 2.5561 - val_accuracy: 0.1204 - val_loss: 2.3005 - learning_rate: 1.0000e-04
# Epoch 3/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.1282 - loss: 2.4451 - val_accuracy: 0.1559 - val_loss: 2.2148 - learning_rate: 1.0000e-04
# Epoch 4/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.1242 - loss: 2.4215 - val_accuracy: 0.1759 - val_loss: 2.1633 - learning_rate: 1.0000e-04
# Epoch 5/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.1369 - loss: 2.3987 - val_accuracy: 0.1926 - val_loss: 2.1167 - learning_rate: 1.0000e-04
# Epoch 6/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.1424 - loss: 2.3442 - val_accuracy: 0.1993 - val_loss: 2.0816 - learning_rate: 1.0000e-04
# Epoch 7/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.1479 - loss: 2.3402 - val_accuracy: 0.2094 - val_loss: 2.0540 - learning_rate: 1.0000e-04
# Epoch 8/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.1542 - loss: 2.3150 - val_accuracy: 0.2201 - val_loss: 2.0221 - learning_rate: 1.0000e-04
# Epoch 9/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.1623 - loss: 2.2797 - val_accuracy: 0.2328 - val_loss: 1.9974 - learning_rate: 1.0000e-04
# Epoch 10/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.1656 - loss: 2.2613 - val_accuracy: 0.2515 - val_loss: 1.9781 - learning_rate: 1.0000e-04
# Epoch 11/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.1572 - loss: 2.2664 - val_accuracy: 0.2569 - val_loss: 1.9565 - learning_rate: 1.0000e-04
# Epoch 12/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.1649 - loss: 2.2328 - val_accuracy: 0.2682 - val_loss: 1.9396 - learning_rate: 1.0000e-04
# Epoch 13/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.1672 - loss: 2.2236 - val_accuracy: 0.2769 - val_loss: 1.9239 - learning_rate: 1.0000e-04
# Epoch 14/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.1680 - loss: 2.2123 - val_accuracy: 0.2863 - val_loss: 1.9098 - learning_rate: 1.0000e-04
# Epoch 15/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.1723 - loss: 2.1956 - val_accuracy: 0.2990 - val_loss: 1.8952 - learning_rate: 1.0000e-04
# Epoch 16/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.1777 - loss: 2.1860 - val_accuracy: 0.3064 - val_loss: 1.8848 - learning_rate: 1.0000e-04
# Epoch 17/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - accuracy: 0.1845 - loss: 2.1723 - val_accuracy: 0.3117 - val_loss: 1.8710 - learning_rate: 1.0000e-04
# Epoch 18/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 19s 82ms/step - accuracy: 0.1883 - loss: 2.1547 - val_accuracy: 0.3191 - val_loss: 1.8576 - learning_rate: 1.0000e-04
# Epoch 19/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.1916 - loss: 2.1554 - val_accuracy: 0.3258 - val_loss: 1.8494 - learning_rate: 1.0000e-04
# Epoch 20/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.2003 - loss: 2.1238 - val_accuracy: 0.3344 - val_loss: 1.8369 - learning_rate: 1.0000e-04
# Epoch 21/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 91ms/step - accuracy: 0.1919 - loss: 2.1363 - val_accuracy: 0.3458 - val_loss: 1.8260 - learning_rate: 1.0000e-04
# Epoch 22/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 19s 84ms/step - accuracy: 0.2008 - loss: 2.1105 - val_accuracy: 0.3525 - val_loss: 1.8155 - learning_rate: 1.0000e-04
# Epoch 23/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.2128 - loss: 2.1068 - val_accuracy: 0.3639 - val_loss: 1.8031 - learning_rate: 1.0000e-04
# Epoch 24/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.2170 - loss: 2.0899 - val_accuracy: 0.3686 - val_loss: 1.7934 - learning_rate: 1.0000e-04
# Epoch 25/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.2078 - loss: 2.0932 - val_accuracy: 0.3753 - val_loss: 1.7829 - learning_rate: 1.0000e-04
# Epoch 26/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.2125 - loss: 2.0950 - val_accuracy: 0.3846 - val_loss: 1.7704 - learning_rate: 1.0000e-04
# Epoch 27/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.2240 - loss: 2.0553 - val_accuracy: 0.3880 - val_loss: 1.7587 - learning_rate: 1.0000e-04
# Epoch 28/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.2137 - loss: 2.0894 - val_accuracy: 0.3946 - val_loss: 1.7484 - learning_rate: 1.0000e-04
# Epoch 29/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.2336 - loss: 2.0534 - val_accuracy: 0.3953 - val_loss: 1.7372 - learning_rate: 1.0000e-04
# Epoch 30/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.2136 - loss: 2.0728 - val_accuracy: 0.3993 - val_loss: 1.7265 - learning_rate: 1.0000e-04
# Final validation accuracy: 39.93%
